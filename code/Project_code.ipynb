# %%
pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ------------------------------------ 253.0/253.0 kB 535.9 kB/s eta 0:00:00
# Requirement already satisfied: numba>=0.51.0 in c:\users\team\anaconda3\lib\site-packages (from librosa) (0.56.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\team\anaconda3\lib\site-packages (from librosa) (1.10.0)
# Requirement already satisfied: msgpack>=1.0 in c:\users\team\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: pooch<1.7,>=1.0 in c:\users\team\anaconda3\lib\site-packages (from librosa) (1.4.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\team\anaconda3\lib\site-packages (from librosa) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\team\anaconda3\lib\site-packages (from librosa) (4.4.0)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 840.8 kB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\team\anaconda3\lib\site-packages (from librosa) (1.2.1)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ------------------------------------ 377.0/377.0 kB 545.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: joblib>=0.14 in c:\users\team\anaconda3\lib\site-packages (from librosa) (1.1.1)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp310-cp310-win_amd64.whl (184 kB)
#      ------------------------------------ 184.0/184.0 kB 695.2 kB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.3.0 in c:\users\team\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: setuptools in c:\users\team\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\team\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: packaging in c:\users\team\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (22.0)
# Requirement already satisfied: appdirs in c:\users\team\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in c:\users\team\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\team\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\team\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\team\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\team\anaconda3\lib\site-packages (from requests->pooch<1.7,>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\team\anaconda3\lib\site-packages (from requests->pooch<1.7,>=1.0->librosa) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\team\anaconda3\lib\site-packages (from requests->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\team\anaconda3\lib\site-packages (from requests->pooch<1.7,>=1.0->librosa) (3.4)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23736 sha256=cf327895e62f8f32fdac90ef2a5cc9ce68b20fba03ab936eef6f141329e10ba2
#   Stored in directory: c:\users\team\appdata\local\pip\cache\wheels\3d\e0\4b\51b8aa4a0e2b6361c14943f7a7c2c7adb7b9cd419e0a1b720d
# Successfully built audioread
# Installing collected packages: soxr, lazy-loader, audioread, soundfile, librosa
# Successfully installed audioread-3.0.0 lazy-loader-0.3 librosa-0.10.0.post2 soundfile-0.12.1 soxr-0.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\team\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\team\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\team\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\team\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\team\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\team\anaconda3\lib\site-packages (3.7.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.20 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\team\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\team\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import binary
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import binary
#
#   File ~\Documents\GitHub\CNN_Aedes_Aegypti_Classifier\code\binary.py:14
#     file_url = 'C:\Users\\TEAM\\Documents\\GitHub\\CNN_Aedes_Aegypti_Classifier\\dataset\\aedes_aegypti'
#                                                                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import csv
import glob
import os
import matplotlib.pyplot as plt

import librosa
import numpy as np
from keras import Sequential
from keras.layers import MaxPooling2D, Conv2D
from keras.layers import Dense, Dropout, Flatten
from sklearn.model_selection import StratifiedKFold
import sklearn.metrics as skm

# %%
import binary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import binary
#
# File ~\Documents\GitHub\CNN_Aedes_Aegypti_Classifier\code\binary.py:113
#     110 recall_scores = []
#     111 f1_scores = []
# --> 113 for i, (train, test) in enumerate(skf.split(X, Y)):
#     114   print("Running Fold", i + 1, "/", n_folds)
#     115   model = None # Clearing the NN.
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:771, in StratifiedKFold.split(self, X, y, groups)
#     737 def split(self, X, y, groups=None):
#     738     """Generate indices to split data into training and test set.
#     739
#     740     Parameters
#    (...)
#     769     to an integer.
#     770     """
# --> 771     y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#     772     return super().split(X, y, groups)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
def load_data():
  tr_sub_dirs = ["0", "1"]
  tr_features, tr_labels = extract_features(tr_sub_dirs)
  np.savez(file_url, tr_features, tr_labels)
  return tr_features, tr_labels
  # Comment the above code and use the code below to not process the files again
  npread = np.load(file_url + '.npz')
  return npread['arr_0'], npread['arr_1']

# %%
def extract_features( sub_dirs, file_ext="*.wav"):
  window_size = hop_length * (frames - 1)
  log_specgrams = []
  labels = []
  for l, sub_dir in enumerate(sub_dirs):
    for fn in glob.glob(os.path.join(file_url, sub_dir, file_ext)):
      sound_clip, _ = librosa.load(fn, sr=sample_rate)
      print('Extracting features from: ' + fn)
      label = fn.split('\\')[-2]
      for (start, end) in windows(sound_clip, window_size):
        if (len(sound_clip[start:end]) == window_size):
          signal = sound_clip[start:end]
          melspec = librosa.feature.melspectrogram(signal, n_mels=bands, sr=sample_rate, n_fft=n_fft, hop_length=hop_length)
          logspec = librosa.power_to_db(melspec, ref=np.max)
          logspec = logspec / 80 + 1
          logspec = logspec.T.flatten()[:, np.newaxis].T
          log_specgrams.append(logspec)
          labels.append(label)
  features = np.asarray(log_specgrams).reshape(len(log_specgrams), bands, frames, 1)
  np_labels = np.array(labels, dtype=int)
  unique, counts = np.unique(np_labels, return_counts=True) # to check the number of samples for each class

  return np.array(features), np_labels

# %%
file_url = (r"C:\Users\TEAM\Documents\GitHub\CNN_Aedes_Aegypti_Classifier\New data")

# %%
import os

def imprimir_carpeta(ruta):
    # Obtener la lista de archivos y carpetas en la ruta especificada
    contenido = os.listdir(ruta)
    
    # Iterar sobre el contenido de la carpeta
    for elemento in contenido:
        # Construir la ruta completa del elemento
        ruta_elemento = os.path.join(ruta, elemento)
        
        # Verificar si es un archivo o una carpeta
        if os.path.isfile(ruta_elemento):
            # Imprimir el nombre del archivo
            print("Archivo:", elemento)
        elif os.path.isdir(ruta_elemento):
            # Imprimir el nombre de la carpeta y explorar su contenido de manera recursiva
            print("Carpeta:", elemento)
            imprimir_carpeta(ruta_elemento)
        else:
            # Imprimir un mensaje si es un elemento desconocido
            print("Elemento desconocido:", elemento)

# Ruta de la carpeta a imprimir
ruta_carpeta = "C:\\Users\\TEAM\\Documents\\GitHub\\CNN_Aedes_Aegypti_Classifier\\dataset"

# Llamar a la función para imprimir la carpeta
imprimir_carpeta(ruta_carpeta)
# Out:
# Carpeta: aedes_aegypti
# Archivo: aedes_aegypti1.wav
# Archivo: aedes_aegypti10.wav
# Archivo: aedes_aegypti11.wav
# Archivo: aedes_aegypti12.wav
# Archivo: aedes_aegypti13.wav
# Archivo: aedes_aegypti14.wav
# Archivo: aedes_aegypti15.wav
# Archivo: aedes_aegypti16.wav
# Archivo: aedes_aegypti17.wav
# Archivo: aedes_aegypti18.wav
# Archivo: aedes_aegypti19.wav
# Archivo: aedes_aegypti2.wav
# Archivo: aedes_aegypti20.wav
# Archivo: aedes_aegypti21.wav
# Archivo: aedes_aegypti22.wav
# Archivo: aedes_aegypti3.wav
# Archivo: aedes_aegypti4.wav
# Archivo: aedes_aegypti5.wav
# Archivo: anopheles_albimanus28.wav
# Archivo: anopheles_albimanus29.wav
# Archivo: anopheles_albimanus3.wav
# Archivo: anopheles_albimanus30.wav
# Archivo: anopheles_albimanus31.wav
# Archivo: anopheles_albimanus32.wav
# Archivo: anopheles_albimanus33.wav
# Archivo: anopheles_albimanus34.wav
# Archivo: anopheles_albimanus35.wav
# Archivo: anopheles_albimanus4.wav
# Archivo: anopheles_albimanus5.wav
# Archivo: anopheles_albimanus6.wav
# Archivo: anopheles_albimanus7.wav
# Archivo: anopheles_albimanus8.wav
# Archivo: anopheles_albimanus9.wav
# Carpeta: anopheles_arabiensis_dongola
# Archivo: anopheles_arabiensis_dongola1.wav
# Archivo: anopheles_arabiensis_dongola2.wav
# Archivo: anopheles_arabiensis_dongola3.wav
# Archivo: anopheles_arabiensis_dongola4.wav
# Archivo: anopheles_arabiensis_dongola5.wav
# Archivo: anopheles_arabiensis_dongola6.wav
# Carpeta: anopheles_arabiensis_rufisque
# Archivo: anopheles_arabiensis_rufisque1.wav
# Archivo: anopheles_arabiensis_rufisque2.wav
# Archivo: anopheles_arabiensis_rufisque3.wav
# Archivo: anopheles_arabiensis_rufisque4.wav
# Archivo: anopheles_arabiensis_rufisque5.wav
# Archivo: anopheles_arabiensis_rufisque6.wav
# Archivo: anopheles_arabiensis_rufisque7.wav
# Carpeta: anopheles_atroparvus
# Archivo: anopheles_atroparvus1.wav
# Archivo: anopheles_atroparvus2.wav
# Archivo: anopheles_atroparvus3.wav
# Archivo: anopheles_atroparvus4.wav
# Archivo: anopheles_atroparvus5.wav
# Archivo: anopheles_atroparvus6.wav
# Archivo: anopheles_atroparvus7.wav
# Carpeta: anopheles_dirus
# Archivo: anopheles_dirus1.wav
# Archivo: anopheles_dirus10.wav
# Archivo: anopheles_dirus11.wav
# Archivo: anopheles_dirus12.wav
# Archivo: anopheles_dirus13.wav
# Archivo: anopheles_dirus14.wav
# Archivo: anopheles_dirus15.wav
# Archivo: anopheles_dirus16.wav
# Archivo: anopheles_dirus17.wav
# Archivo: anopheles_dirus18.wav
# Archivo: anopheles_dirus19.wav
# Archivo: anopheles_dirus2.wav
# Archivo: anopheles_dirus20.wav
# Archivo: anopheles_dirus21.wav
# Archivo: anopheles_dirus22.wav
# Archivo: anopheles_dirus23.wav
# Archivo: anopheles_dirus24.wav
# Archivo: anopheles_dirus25.wav
# Archivo: anopheles_dirus26.wav
# Archivo: anopheles_dirus27.wav
# Archivo: anopheles_dirus28.wav
# Archivo: anopheles_dirus29.wav
# Archivo: anopheles_dirus3.wav
# Archivo: anopheles_dirus30.wav
# Archivo: anopheles_dirus31.wav
# Archivo: anopheles_dirus32.wav
# Archivo: anopheles_dirus33.wav
# Archivo: anopheles_dirus34.wav
# Archivo: anopheles_dirus35.wav
# Archivo: anopheles_dirus36.wav
# Archivo: anopheles_dirus37.wav
# Archivo: anopheles_dirus38.wav
# Archivo: anopheles_dirus39.wav
# Archivo: anopheles_dirus4.wav
# Archivo: anopheles_dirus40.wav
# Archivo: anopheles_dirus41.wav
# Archivo: anopheles_dirus42.wav
# Archivo: anopheles_dirus43.wav
# Archivo: anopheles_dirus44.wav
# Archivo: anopheles_dirus5.wav
# Archivo: anopheles_dirus6.wav
# Archivo: anopheles_dirus7.wav
# Archivo: anopheles_dirus8.wav
# Archivo: anopheles_dirus9.wav
# Carpeta: anopheles_farauti
# Archivo: anopheles_farauti1.wav
# Archivo: anopheles_farauti10.wav
# Archivo: anopheles_farauti11.wav
# Archivo: anopheles_farauti12.wav
# Archivo: anopheles_farauti13.wav
# Archivo: anopheles_farauti14.wav
# Archivo: anopheles_farauti15.wav
# Archivo: anopheles_farauti16.wav
# Archivo: anopheles_farauti17.wav
# Archivo: anopheles_farauti18.wav
# Archivo: anopheles_farauti19.wav
# Archivo: anopheles_farauti2.wav
# Archivo: anopheles_farauti20.wav
# Archivo: anopheles_farauti21.wav
# Archivo: anopheles_farauti22.wav
# Archivo: anopheles_farauti23.wav
# Archivo: anopheles_farauti24.wav
# Archivo: anopheles_farauti25.wav
# Archivo: anopheles_farauti26.wav
# Archivo: anopheles_farauti27.wav
# Archivo: anopheles_farauti28.wav
# Archivo: anopheles_farauti29.wav
# Archivo: anopheles_farauti3.wav
# Archivo: anopheles_farauti30.wav
# Archivo: anopheles_farauti31.wav
# Archivo: anopheles_farauti32.wav
# Archivo: anopheles_farauti33.wav
# Archivo: anopheles_farauti34.wav
# Archivo: anopheles_farauti35.wav
# Archivo: anopheles_farauti36.wav
# Archivo: anopheles_farauti37.wav
# Archivo: anopheles_farauti38.wav
# Archivo: anopheles_farauti39.wav
# Archivo: anopheles_farauti4.wav
# Archivo: anopheles_farauti40.wav
# Archivo: anopheles_farauti41.wav
# Archivo: anopheles_farauti42.wav
# Archivo: anopheles_farauti43.wav
# Archivo: anopheles_farauti44.wav
# Archivo: anopheles_farauti45.wav
# Archivo: anopheles_farauti5.wav
# Archivo: anopheles_farauti6.wav
# Archivo: anopheles_farauti7.wav
# Archivo: anopheles_farauti8.wav
# Archivo: anopheles_farauti9.wav
# Carpeta: anopheles_freeborni
# Archivo: anopheles_freeborni1.wav
# Archivo: anopheles_freeborni10.wav
# Archivo: anopheles_freeborni11.wav
# Archivo: anopheles_freeborni12.wav
# Archivo: anopheles_freeborni13.wav
# Archivo: anopheles_freeborni14.wav
# Archivo: anopheles_freeborni15.wav
# Archivo: anopheles_freeborni16.wav
# Archivo: anopheles_freeborni17.wav
# Archivo: anopheles_freeborni18.wav
# Archivo: anopheles_freeborni19.wav
# Archivo: anopheles_freeborni2.wav
# Archivo: anopheles_freeborni20.wav
# Archivo: anopheles_freeborni21.wav
# Archivo: anopheles_freeborni22.wav
# Archivo: anopheles_freeborni23.wav
# Archivo: anopheles_freeborni24.wav
# Archivo: anopheles_freeborni25.wav
# Archivo: anopheles_freeborni26.wav
# Archivo: anopheles_freeborni27.wav
# Archivo: anopheles_freeborni28.wav
# Archivo: anopheles_freeborni29.wav
# Archivo: anopheles_freeborni3.wav
# Archivo: anopheles_freeborni30.wav
# Archivo: anopheles_freeborni31.wav
# Archivo: anopheles_freeborni32.wav
# Archivo: anopheles_freeborni33.wav
# Archivo: anopheles_freeborni34.wav
# Archivo: anopheles_freeborni35.wav
# Archivo: anopheles_freeborni36.wav
# Archivo: anopheles_freeborni37.wav
# Archivo: anopheles_freeborni38.wav
# Archivo: anopheles_freeborni39.wav
# Archivo: anopheles_freeborni4.wav
# Archivo: anopheles_freeborni40.wav
# Archivo: anopheles_freeborni41.wav
# Archivo: anopheles_freeborni42.wav
# Archivo: anopheles_freeborni43.wav
# Archivo: anopheles_freeborni44.wav
# Archivo: anopheles_freeborni45.wav
# Archivo: anopheles_freeborni46.wav
# Archivo: anopheles_freeborni47.wav
# Archivo: anopheles_freeborni48.wav
# Archivo: anopheles_freeborni49.wav
# Archivo: anopheles_freeborni5.wav
# Archivo: anopheles_freeborni50.wav
# Archivo: anopheles_freeborni51.wav
# Archivo: anopheles_freeborni52.wav
# Archivo: anopheles_freeborni53.wav
# Archivo: anopheles_freeborni54.wav
# Archivo: anopheles_freeborni6.wav
# Archivo: anopheles_freeborni7.wav
# Archivo: anopheles_freeborni8.wav
# Archivo: anopheles_freeborni9.wav
# Carpeta: anopheles_gambiae_akron
# Archivo: anopheles_gambiae_akron1.wav
# Archivo: anopheles_gambiae_akron2.wav
# Archivo: anopheles_gambiae_akron3.wav
# Archivo: anopheles_gambiae_akron4.wav
# Archivo: anopheles_gambiae_akron5.wav
# Archivo: anopheles_gambiae_akron6.wav
# Archivo: anopheles_gambiae_akron7.wav
# Archivo: anopheles_gambiae_akron8.wav
# Carpeta: anopheles_gambiae_kisumu
# Archivo: anopheles_gambiae_kisumu1.wav
# Archivo: anopheles_gambiae_kisumu10.wav
# Archivo: anopheles_gambiae_kisumu11.wav
# Archivo: anopheles_gambiae_kisumu12.wav
# Archivo: anopheles_gambiae_kisumu13.wav
# Archivo: anopheles_gambiae_kisumu14.wav
# Archivo: anopheles_gambiae_kisumu15.wav
# Archivo: anopheles_gambiae_kisumu16.wav
# Archivo: anopheles_gambiae_kisumu17.wav
# Archivo: anopheles_gambiae_kisumu18.wav
# Archivo: anopheles_gambiae_kisumu19.wav
# Archivo: anopheles_gambiae_kisumu2.wav
# Archivo: anopheles_gambiae_kisumu20.wav
# Archivo: anopheles_gambiae_kisumu21.wav
# Archivo: anopheles_gambiae_kisumu22.wav
# Archivo: anopheles_gambiae_kisumu23.wav
# Archivo: anopheles_gambiae_kisumu24.wav
# Archivo: anopheles_gambiae_kisumu25.wav
# Archivo: anopheles_gambiae_kisumu26.wav
# Archivo: anopheles_gambiae_kisumu27.wav
# Archivo: anopheles_gambiae_kisumu28.wav
# Archivo: anopheles_gambiae_kisumu29.wav
# Archivo: anopheles_gambiae_kisumu3.wav
# Archivo: anopheles_gambiae_kisumu30.wav
# Archivo: anopheles_gambiae_kisumu31.wav
# Archivo: anopheles_gambiae_kisumu32.wav
# Archivo: anopheles_gambiae_kisumu33.wav
# Archivo: anopheles_gambiae_kisumu34.wav
# Archivo: anopheles_gambiae_kisumu35.wav
# Archivo: anopheles_gambiae_kisumu36.wav
# Archivo: anopheles_gambiae_kisumu37.wav
# Archivo: anopheles_gambiae_kisumu38.wav
# Archivo: anopheles_gambiae_kisumu39.wav
# Archivo: anopheles_gambiae_kisumu4.wav
# Archivo: anopheles_gambiae_kisumu40.wav
# Archivo: anopheles_gambiae_kisumu41.wav
# Archivo: anopheles_gambiae_kisumu42.wav
# Archivo: anopheles_gambiae_kisumu5.wav
# Archivo: anopheles_gambiae_kisumu6.wav
# Archivo: anopheles_gambiae_kisumu7.wav
# Archivo: anopheles_gambiae_kisumu8.wav
# Archivo: anopheles_gambiae_kisumu9.wav
# Carpeta: anopheles_gambiae_rsp
# Archivo: anopheles_gambiae_rsp1.wav
# Archivo: anopheles_gambiae_rsp2.wav
# Carpeta: anopheles_merus
# Archivo: anopheles_merus1.wav
# Archivo: anopheles_merus2.wav
# Archivo: anopheles_merus3.wav
# Archivo: anopheles_merus4.wav
# Archivo: anopheles_merus5.wav
# Carpeta: anopheles_minimus
# Archivo: anopheles_minimus1.wav
# Archivo: anopheles_minimus10.wav
# Archivo: anopheles_minimus11.wav
# Archivo: anopheles_minimus12.wav
# Archivo: anopheles_minimus13.wav
# Archivo: anopheles_minimus14.wav
# Archivo: anopheles_minimus15.wav
# Archivo: anopheles_minimus16.wav
# Archivo: anopheles_minimus17.wav
# Archivo: anopheles_minimus18.wav
# Archivo: anopheles_minimus19.wav
# Archivo: anopheles_minimus2.wav
# Archivo: anopheles_minimus20.wav
# Archivo: anopheles_minimus21.wav
# Archivo: anopheles_minimus22.wav
# Archivo: anopheles_minimus23.wav
# Archivo: anopheles_minimus24.wav
# Archivo: anopheles_minimus25.wav
# Archivo: anopheles_minimus26.wav
# Archivo: anopheles_minimus27.wav
# Archivo: anopheles_minimus28.wav
# Archivo: anopheles_minimus29.wav
# Archivo: anopheles_minimus3.wav
# Archivo: anopheles_minimus30.wav
# Archivo: anopheles_minimus31.wav
# Archivo: anopheles_minimus32.wav
# Archivo: anopheles_minimus33.wav
# Archivo: anopheles_minimus34.wav
# Archivo: anopheles_minimus35.wav
# Archivo: anopheles_minimus36.wav
# Archivo: anopheles_minimus37.wav
# Archivo: anopheles_minimus38.wav
# Archivo: anopheles_minimus39.wav
# Archivo: anopheles_minimus4.wav
# Archivo: anopheles_minimus40.wav
# Archivo: anopheles_minimus41.wav
# Archivo: anopheles_minimus42.wav
# Archivo: anopheles_minimus43.wav
# Archivo: anopheles_minimus44.wav
# Archivo: anopheles_minimus45.wav
# Archivo: anopheles_minimus46.wav
# Archivo: anopheles_minimus47.wav
# Archivo: anopheles_minimus48.wav
# Archivo: anopheles_minimus49.wav
# Archivo: anopheles_minimus5.wav
# Archivo: anopheles_minimus50.wav
# Archivo: anopheles_minimus51.wav
# Archivo: anopheles_minimus52.wav
# Archivo: anopheles_minimus53.wav
# Archivo: anopheles_minimus54.wav
# Archivo: anopheles_minimus55.wav
# Archivo: anopheles_minimus56.wav
# Archivo: anopheles_minimus57.wav
# Archivo: anopheles_minimus58.wav
# Archivo: anopheles_minimus59.wav
# Archivo: anopheles_minimus6.wav
# Archivo: anopheles_minimus60.wav
# Archivo: anopheles_minimus61.wav
# Archivo: anopheles_minimus62.wav
# Archivo: anopheles_minimus63.wav
# Archivo: anopheles_minimus64.wav
# Archivo: anopheles_minimus7.wav
# Archivo: anopheles_minimus8.wav
# Archivo: anopheles_minimus9.wav
# Carpeta: anopheles_quadriannulatus
# Archivo: anopheles_quadriannulatus1.wav
# Archivo: anopheles_quadriannulatus2.wav
# Archivo: anopheles_quadriannulatus3.wav
# Archivo: anopheles_quadriannulatus4.wav
# Archivo: anopheles_quadriannulatus5.wav
# Archivo: anopheles_quadriannulatus6.wav
# Archivo: anopheles_quadriannulatus7.wav
# Carpeta: anopheles_quadrimaculatus
# Archivo: anopheles_quadrimaculatus1.wav
# Archivo: anopheles_quadrimaculatus2.wav
# Archivo: anopheles_quadrimaculatus3.wav
# Archivo: anopheles_quadrimaculatus4.wav
# Archivo: anopheles_quadrimaculatus5.wav
# Archivo: anopheles_quadrimaculatus6.wav
# Carpeta: anopheles_stephensi
# Archivo: anopheles_stephensi1.wav
# Archivo: anopheles_stephensi10.wav
# Archivo: anopheles_stephensi11.wav
# Archivo: anopheles_stephensi12.wav
# Archivo: anopheles_stephensi13.wav
# Archivo: anopheles_stephensi14.wav
# Archivo: anopheles_stephensi15.wav
# Archivo: anopheles_stephensi16.wav
# Archivo: anopheles_stephensi17.wav
# Archivo: anopheles_stephensi18.wav
# Archivo: anopheles_stephensi19.wav
# Archivo: anopheles_stephensi2.wav
# Archivo: anopheles_stephensi20.wav
# Archivo: anopheles_stephensi21.wav
# Archivo: anopheles_stephensi22.wav
# Archivo: anopheles_stephensi23.wav
# Archivo: anopheles_stephensi24.wav
# Archivo: anopheles_stephensi25.wav
# Archivo: anopheles_stephensi26.wav
# Archivo: anopheles_stephensi27.wav
# Archivo: anopheles_stephensi28.wav
# Archivo: anopheles_stephensi29.wav
# Archivo: anopheles_stephensi3.wav
# Archivo: anopheles_stephensi30.wav
# Archivo: anopheles_stephensi31.wav
# Archivo: anopheles_stephensi32.wav
# Archivo: anopheles_stephensi33.wav
# Archivo: anopheles_stephensi34.wav
# Archivo: anopheles_stephensi35.wav
# Archivo: anopheles_stephensi36.wav
# Archivo: anopheles_stephensi37.wav
# Archivo: anopheles_stephensi38.wav
# Archivo: anopheles_stephensi39.wav
# Archivo: anopheles_stephensi4.wav
# Archivo: anopheles_stephensi40.wav
# Archivo: anopheles_stephensi41.wav
# Archivo: culiseta_incidens30.wav
# Archivo: culiseta_incidens4.wav
# Archivo: culiseta_incidens5.wav
# Archivo: culiseta_incidens6.wav
# Archivo: culiseta_incidens7.wav
# Archivo: culiseta_incidens8.wav
# Archivo: culiseta_incidens9.wav

# %%
seed = 123
np.random.seed(seed)  # for reproducibility



bands = 60
frames = 40
hop_length = 256
n_fft = 1024

sample_rate = 8000

n_folds = 10
X, Y = load_data()

skf = StratifiedKFold(n_splits=n_folds, shuffle=True)

accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for i, (dataset, test) in enumerate(skf.split(X, Y)):
  print("Running Fold", i + 1, "/", n_folds)
  model = None # Clearing the NN.
  model = create_model()

  # Generate batches from indices
  xtrain, xval = X[dataset], X[test]
  ytrain, yval = Y[dataset], Y[test]
  accuracy, precision, recall, f1 = train_and_evaluate_model(model, xtrain, ytrain, xval, yval)
  accuracy_scores.append(accuracy)
  precision_scores.append(precision)
  recall_scores.append(recall)
  f1_scores.append(f1)

print("Accuracy scores: " + str(accuracy_scores))
print("Precision scores: " + str(precision_scores))
print("Recall scores: " + str(recall_scores))
print("F1 scores: " + str(f1_scores))

csv_filename = "binary.csv"

with open(csv_filename, 'w', newline='') as csv_file:
  csv_writer = csv.writer(csv_file, delimiter=',')
  csv_writer.writerow(['accuracy', 'precision', 'recall', 'f1_score'])

  for i in range(len(accuracy_scores)):
    csv_writer.writerow([accuracy_scores[i], precision_scores[i], recall_scores[i], f1_scores[i]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 23
#      20 recall_scores = []
#      21 f1_scores = []
# ---> 23 for i, (train, test) in enumerate(skf.split(X, Y)):
#      24   print("Running Fold", i + 1, "/", n_folds)
#      25   model = None # Clearing the NN.
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:771, in StratifiedKFold.split(self, X, y, groups)
#     737 def split(self, X, y, groups=None):
#     738     """Generate indices to split data into training and test set.
#     739
#     740     Parameters
#    (...)
#     769     to an integer.
#     770     """
# --> 771     y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#     772     return super().split(X, y, groups)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
import csv
import glob
import os
import matplotlib.pyplot as plt

import librosa
import numpy as np
from keras import Sequential
from keras.layers import MaxPooling2D, Conv2D
from keras.layers import Dense, Dropout, Flatten
from sklearn.model_selection import StratifiedKFold
import sklearn.metrics as skm

file_url = (r"C:\Users\TEAM\Documents\GitHub\Nueva carpeta")

def windows(data, window_size):
  start = 0
  while start < len(data):
    yield start, start + window_size
    start += (window_size // 2)
print("Hola")
# Out:
# Hola

# %%
def extract_features( sub_dirs, file_ext="*.wav"):
  window_size = hop_length * (frames - 1)
  log_specgrams = []
  labels = []
  for l, sub_dir in enumerate(sub_dirs):
    for fn in glob.glob(os.path.join(file_url, sub_dir, file_ext)):
      sound_clip, _ = librosa.load(fn, sr=sample_rate)
      print('Extracting features from: ' + fn)
      label = fn.split('\\')[-2]
      for (start, end) in windows(sound_clip, window_size):
        if (len(sound_clip[start:end]) == window_size):
          signal = sound_clip[start:end]
          melspec = librosa.feature.melspectrogram(signal, n_mels=bands, sr=sample_rate, n_fft=n_fft, hop_length=hop_length)
          logspec = librosa.power_to_db(melspec, ref=np.max)
          logspec = logspec / 80 + 1
          logspec = logspec.T.flatten()[:, np.newaxis].T
          log_specgrams.append(logspec)
          labels.append(label)
  features = np.asarray(log_specgrams).reshape(len(log_specgrams), bands, frames, 1)
  np_labels = np.array(labels, dtype=int)
  unique, counts = np.unique(np_labels, return_counts=True) # to check the number of samples for each class

  return np.array(features), np_labels
print("Hola")
# Out:
# Hola

# %%
def load_data():
  tr_sub_dirs = ["0", "1"]
  tr_features, tr_labels = extract_features(tr_sub_dirs)
  np.savez(file_url, tr_features, tr_labels)
  return tr_features, tr_labels
  # Comment the above code and use the code below to not process the files again
  npread = np.load(file_url + '.npz')
  return npread['arr_0'], npread['arr_1']
print("Hola")
# Out:
# Hola

# %%
def create_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(bands, frames, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dense(2, activation='sigmoid'))
  model.compile(loss='sparse_categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])
  model.summary()
  
  return model
print("HOLA")
# Out:
# HOLA

# %%
def train_and_evaluate_model(model, xtrain, ytrain, xval, yval):
  model.fit(xtrain, ytrain,  batch_size=32, epochs=10, verbose=2)
  y_predicted_classes = model.predict_classes(xval)
  y_predicted_probability = model.predict(xval)
  conf_matrix = skm.confusion_matrix(yval, y_predicted_classes, labels=[1, 0])
  print("Confusion matrix: \n"  + str(conf_matrix))
  score = model.evaluate(xval, yval, verbose=0)
  print("Accuracy: %.2f%%" % ( score[1] * 100))
  precision = skm.precision_score(yval, y_predicted_classes, pos_label=0)
  print("Precision: %.2f%%" % (precision*100))
  recall = skm.recall_score(yval, y_predicted_classes, pos_label=0)
  print("Recall: %.2f%%" % (recall*100))
  f1_score = skm.f1_score(yval, y_predicted_classes, pos_label=0)
  print("F1-score: %.4f" % f1_score)
  auroc = skm.roc_auc_score(yval, y_predicted_classes)
  print("AUROC: %.4f" % auroc)

  return score[1], precision, recall, f1_score
print("HOLA")
# Out:
# HOLA

# %%
if len(X) == 0 or len(Y) == 0:
    print("Error: Los arreglos X e Y deben contener al menos una muestra.")
else:
    for i, (train, test) in enumerate(skf.split(X, Y)):
        print("Running Fold", i + 1, "/", n_folds)
    
    model = None  # Limpiando la NN.
    model = create_model()
# Out:
# Error: Los arreglos X e Y deben contener al menos una muestra.

# %%
chmod +w r"C:\Users\TEAM\Documents\GitHub\CNN_Aedes_Aegypti_Classifier\train"
# Out:
#   Cell In[70], line 1
#     chmod +w r"C:\Users\TEAM\Documents\GitHub\CNN_Aedes_Aegypti_Classifier\train"
#              ^
# SyntaxError: invalid syntax

# %%
seed = 123
np.random.seed(seed)  # for reproducibility



bands = 60
frames = 40
hop_length = 256
n_fft = 1024

sample_rate = 8000

n_folds = 11
X, Y = load_data()

skf = StratifiedKFold(n_splits=n_folds, shuffle=True)

accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for i, (train, test) in enumerate(skf.split(X, Y)):
  print("Running Fold", i + 1, "/", n_folds)
model = None # Clearing the NN.
model = create_model()

  # Generate batches from indices
xtrain, xval = X[train], X[test]
ytrain, yval = Y[train], Y[test]
accuracy, precision, recall, f1 = train_and_evaluate_model(model, xtrain, ytrain, xval, yval)
accuracy_scores.append(accuracy)
precision_scores.append(precision)
recall_scores.append(recall)
f1_scores.append(f1)

print("Accuracy scores: " + str(accuracy_scores))
print("Precision scores: " + str(precision_scores))
print("Recall scores: " + str(recall_scores))
print("F1 scores: " + str(f1_scores))

csv_filename = "binary_pro.csv"

with open(csv_filename, 'w', newline='') as csv_file:
  csv_writer = csv.writer(csv_file, delimiter=',')
  csv_writer.writerow(['accuracy', 'precision', 'recall', 'f1_score'])

  for i in range(len(accuracy_scores)):
    csv_writer.writerow([accuracy_scores[i], precision_scores[i], recall_scores[i], f1_scores[i]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 23
#      20 recall_scores = []
#      21 f1_scores = []
# ---> 23 for i, (train, test) in enumerate(skf.split(X, Y)):
#      24   print("Running Fold", i + 1, "/", n_folds)
#      25 model = None # Clearing the NN.
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:771, in StratifiedKFold.split(self, X, y, groups)
#     737 def split(self, X, y, groups=None):
#     738     """Generate indices to split data into training and test set.
#     739
#     740     Parameters
#    (...)
#     769     to an integer.
#     770     """
# --> 771     y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#     772     return super().split(X, y, groups)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
import binary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import binary
#
# File ~\Documents\GitHub\CNN_Aedes_Aegypti_Classifier\code\binary.py:113
#     110 recall_scores = []
#     111 f1_scores = []
# --> 113 for i, (train, test) in enumerate(skf.split(X, Y)):
#     114   print("Running Fold", i + 1, "/", n_folds)
#     115 model = None # Clearing the NN.
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:771, in StratifiedKFold.split(self, X, y, groups)
#     737 def split(self, X, y, groups=None):
#     738     """Generate indices to split data into training and test set.
#     739
#     740     Parameters
#    (...)
#     769     to an integer.
#     770     """
# --> 771     y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#     772     return super().split(X, y, groups)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
import csv
import glob
import os
import matplotlib.pyplot as plt

import librosa
import numpy as np
from keras import Sequential
from keras.layers import MaxPooling2D, Conv2D
from keras.layers import Dense, Dropout, Flatten
from sklearn.model_selection import StratifiedKFold
import sklearn.metrics as skm

file_url = (r"C:\Users\TEAM\Documents\GitHub\Train")

def windows(data, window_size):
  start = 0
  while start < len(data):
    yield start, start + window_size
    start += (window_size // 2)

def extract_features( sub_dirs, file_ext="*.wav"):
  window_size = hop_length * (frames - 1)
  log_specgrams = []
  labels = []
  for l, sub_dir in enumerate(sub_dirs):
    for fn in glob.glob(os.path.join(file_url, sub_dir, file_ext)):
      sound_clip, _ = librosa.load(fn, sr=sample_rate)
      print('Extracting features from: ' + fn)
      label = fn.split('\\')[-2]
      for (start, end) in windows(sound_clip, window_size):
        if (len(sound_clip[start:end]) == window_size):
          signal = sound_clip[start:end]
          melspec = librosa.feature.melspectrogram(signal, n_mels=bands, sr=sample_rate, n_fft=n_fft, hop_length=hop_length)
          logspec = librosa.power_to_db(melspec, ref=np.max)
          logspec = logspec / 80 + 1
          logspec = logspec.T.flatten()[:, np.newaxis].T
          log_specgrams.append(logspec)
          labels.append(label)
  features = np.asarray(log_specgrams).reshape(len(log_specgrams), bands, frames, 1)
  np_labels = np.array(labels, dtype=int)
  unique, counts = np.unique(np_labels, return_counts=True) # to check the number of samples for each class

  return np.array(features), np_labels

def load_data():
  tr_sub_dirs = ["0", "1"]
  tr_features, tr_labels = extract_features(tr_sub_dirs)
  np.savez(file_url, tr_features, tr_labels)
  return tr_features, tr_labels
  # Comment the above code and use the code below to not process the files again
  npread = np.load(file_url + '.npz')
  return npread['arr_0'], npread['arr_1']

def create_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(bands, frames, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dense(2, activation='sigmoid'))
  model.compile(loss='sparse_categorical_crossentropy',
                optimizer='rmsprop',
                metrics=['accuracy'])
  model.summary()
  
  return model

def train_and_evaluate_model(model, xtrain, ytrain, xval, yval):
  model.fit(xtrain, ytrain,  batch_size=32, epochs=10, verbose=2)
  y_predicted_classes = model.predict_classes(xval)
  y_predicted_probability = model.predict(xval)
  conf_matrix = skm.confusion_matrix(yval, y_predicted_classes, labels=[1, 0])
  print("Confusion matrix: \n"  + str(conf_matrix))
  score = model.evaluate(xval, yval, verbose=0)
  print("Accuracy: %.2f%%" % ( score[1] * 100))
  precision = skm.precision_score(yval, y_predicted_classes, pos_label=0)
  print("Precision: %.2f%%" % (precision*100))
  recall = skm.recall_score(yval, y_predicted_classes, pos_label=0)
  print("Recall: %.2f%%" % (recall*100))
  f1_score = skm.f1_score(yval, y_predicted_classes, pos_label=0)
  print("F1-score: %.4f" % f1_score)
  auroc = skm.roc_auc_score(yval, y_predicted_classes)
  print("AUROC: %.4f" % auroc)

  return score[1], precision, recall, f1_score

seed = 123
np.random.seed(seed)  # for reproducibility



bands = 60
frames = 40
hop_length = 256
n_fft = 1024

sample_rate = 8000

n_folds = 10
X, Y = load_data()

skf = StratifiedKFold(X, Y, n_splits=n_folds, shuffle=True)

accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for i, (train, test) in enumerate(skf.split(X, Y)):
  print("Running Fold", i + 1, "/", n_folds)
model = None # Clearing the NN.
model = create_model()

  # Generate batches from indices
xtrain, xval = X[train], X[test]
ytrain, yval = Y[train], Y[test]
accuracy, precision, recall, f1 = train_and_evaluate_model(model, xtrain, ytrain, xval, yval)
accuracy_scores.append(accuracy)
precision_scores.append(precision)
recall_scores.append(recall)
f1_scores.append(f1)

print("Accuracy scores: " + str(accuracy_scores))
print("Precision scores: " + str(precision_scores))
print("Recall scores: " + str(recall_scores))
print("F1 scores: " + str(f1_scores))

csv_filename = "binary_pro.csv"

with open(csv_filename, 'w', newline='') as csv_file:
  csv_writer = csv.writer(csv_file, delimiter=',')
  csv_writer.writerow(['accuracy', 'precision', 'recall', 'f1_score'])

  for i in range(len(accuracy_scores)):
    csv_writer.writerow([accuracy_scores[i], precision_scores[i], recall_scores[i], f1_scores[i]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 106
#     103 n_folds = 10
#     104 X, Y = load_data()
# --> 106 skf = StratifiedKFold(X, Y, n_splits=n_folds, shuffle=True)
#     108 accuracy_scores = []
#     109 precision_scores = []
#
# TypeError: StratifiedKFold.__init__() got multiple values for argument 'n_splits'

# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\team\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\team\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\team\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\team\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\team\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
